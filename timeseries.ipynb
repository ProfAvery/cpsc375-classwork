# %% [markdown]
# # CPSC 375 Classwork - Time Series Decomposition
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ProfAvery/cpsc375-classwork/blob/main/timeseries.ipynb)
#
# - *Manager*:
# - *Recorder*:
# - *Presenter*:
# - *Timekeeper*:

# %% [markdown]
# *Note*: On Google Colab, run the following code cell to download the `cpsc375` module before trying to `import`:

# %%
# !mkdir -p ./cpsc375 && wget --quiet --timestamping https://raw.githubusercontent.com/ProfAvery/cpsc375-classwork/refs/heads/main/cpsc375/__init__.py --output-document=./cpsc375/__init__.py

# %%
from cpsc375 import *

# %% [markdown]
# ## Slide 29
#
# Read the text CSV file at https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv which describes the minimum daily temperatures over 10 years (1981-1990) in Melbourne, Australia. The goal is to convert this to a Pandas time series with the appropriate frequency and then decompose it into trend, seasonal, and random components.
#
# Write Python code to do the following:
# * Read the file into a `DataFrame` object (Hint: use `pd.read_csv()` with `parse_dates` to convert to a `datetime64` object and `index_col` to convert to `DatetimeIndex`)

# %% [markdown]
# * Find the frequency of the seasonal component (Hint: use `plot_acf()` with a large `lags` parameter value)

# %% [markdown]
# Decompose the `DataFrame` object
