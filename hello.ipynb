# %% [markdown]
# # CPSC 375 Classwork - Hello, world
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ProfAvery/cpsc375-classwork/blob/main/hello.ipynb)
#
# - *Manager*:
# - *Recorder*:
# - *Presenter*:
# - *Timekeeper*:

# %% [markdown]
# *Note*: On Google Colab, run the following code cell to download the `cpsc375` module before trying to `import`:

# %%
# !mkdir -p ./cpsc375 && wget --quiet --timestamping https://raw.githubusercontent.com/ProfAvery/cpsc375-classwork/refs/heads/main/cpsc375/__init__.py --output-document=./cpsc375/__init__.py

# %%
from cpsc375 import *

# %% [markdown]
# ## Slide 4

# %%
plt.text(0.5, 0.5, 'Hello, world.')
